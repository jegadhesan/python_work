# %%
# How tha data is loaded

# %%
import pandas as pd
import numpy as np

file1= 'IVT_2023.xlsx'
file2= 'IVT_2024.xlsx'

df1 = pd.read_excel(file1, sheet_name='Member')
df1
# Out:
#                                            Member Table Unnamed: 1 Unnamed: 2  \
# 0                                 Member Table Analysis        NaN        NaN
# 1                                                   NaN        NaN        NaN
# 2                                          Record Count     100469        NaN
# 3                               Total Number of Members      34034        NaN
# 4     Number of Members Enrolled Anytime\n          ...      34034        NaN
# ...                                                 ...        ...        ...
# 1104                                                NaN        NaN        NaN
# 1105                                                NaN        NaN        NaN
# 1106                                                NaN        NaN        NaN
# 1107                                                NaN        NaN        NaN
# 1108                                                NaN          0        NaN
#
# ...

# %%
# How it claened up

# %%
# For Sheet name member
# Issues: No key emelemets, no sorting, automated sortjing not possible based on the data 
df1 = pd.read_excel(file1, sheet_name='Member')
df2 = pd.read_excel(file2, sheet_name='Member')

df1  = df1.set_axis(['key', *df1.columns[1:]], axis=1)
df2  = df2.set_axis(['key', *df2.columns[1:]], axis=1)
df1  = df1.dropna(axis=0, subset=['key'])
df2  = df2.dropna(axis=0, subset=['key'])
df1 = df1.loc[:,~df1.columns.duplicated()].copy()
df2 = df2.loc[:,~df2.columns.duplicated()].copy()

df1
#colormat = df1.eq(df2).replace({False: 'background-color: lightcoral',True: 'background-color: wheat'})
#df1.style.apply(lambda _: colormat, axis=None).to_excel('Member.xlsx', engine="openpyxl")
# Out:
#                                                    key    Unnamed: 1  \
# 0                                Member Table Analysis           NaN
# 2                                         Record Count        100469
# 3                              Total Number of Members         34034
# 4    Number of Members Enrolled Anytime\n          ...         34034
# 5                                 Total Member Months*        522159
# ..                                                 ...           ...
# 139                 Top 30 Map_Src and Coverage Status  Record Count
# 140                                              1 SUB         48006
# 141                                              1 DEP         35777
# 142                                              1 SPS         16657
# 143                                              1 UNK            29
#
#     Unnamed: 2  Unnamed: 3                   Unnamed: 4  Unnamed: 5
# 0          NaN         NaN                          NaN         NaN
# ...

# %%
df1.compare(df2,align_axis=1,keep_shape = True,keep_equal=True)
# Out:
#                                                    key  \
#                                                   self
# 0                                Member Table Analysis
# 2                                         Record Count
# 3                              Total Number of Members
# 4    Number of Members Enrolled Anytime\n          ...
# 5                                 Total Member Months*
# ..                                                 ...
# 139                 Top 30 Map_Src and Coverage Status
# 140                                              1 SUB
# 141                                              1 DEP
# 142                                              1 SPS
# 143                                              1 UNK
#
#                                                           Unnamed: 1  \
#                                                  other          self
# 0                                Member Table Analysis           NaN
# ...

# %%
df1.eq(df2)
# Out:
#        key      1      2      3      4      5
# 0     True  False  False  False  False  False
# 1     True  False  False  False  False  False
# 3     True  False  False  False   True  False
# 4     True  False  False  False   True  False
# 5     True  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...
# 140   True   True   True  False  False  False
# 141   True  False  False  False  False  False
# 142  False  False  False  False  False  False
# 143  False  False  False  False  False  False
# 144  False  False  False  False  False  False
#
# [114 rows x 6 columns]

# %%
df= df1.compare(df2,align_axis=1,keep_shape = True, keep_equal=True)
df.columns
# Out:
# MultiIndex([(       'key',  'self'),
#             (       'key', 'other'),
#             ('Unnamed: 1',  'self'),
#             ('Unnamed: 1', 'other'),
#             ('Unnamed: 2',  'self'),
#             ('Unnamed: 2', 'other'),
#             ('Unnamed: 3',  'self'),
#             ('Unnamed: 3', 'other'),
#             ('Unnamed: 4',  'self'),
#             ('Unnamed: 4', 'other'),
#             ('Unnamed: 5',  'self'),
#             ('Unnamed: 5', 'other')],
#            )

# %%
df['A_C_equal'] = df.apply(lambda row: ('Unnamed: 1', 'other') == ('Unnamed: 1', 'self'), axis=1)
df
# Out:
#                                                    key  \
#                                                   self
# 0                                Member Table Analysis
# 2                                         Record Count
# 3                              Total Number of Members
# 4    Number of Members Enrolled Anytime\n          ...
# 5                                 Total Member Months*
# ..                                                 ...
# 139                 Top 30 Map_Src and Coverage Status
# 140                                              1 SUB
# 141                                              1 DEP
# 142                                              1 SPS
# 143                                              1 UNK
#
#                                                           Unnamed: 1  \
#                                                  other          self
# 0                                Member Table Analysis           NaN
# ...

# %%
df.style.map(lambda x: "background-color: lightgreen" if x==0 else "background-color: ''")
# Out:
# <style type="text/css">
# ...
